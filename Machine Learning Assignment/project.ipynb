# %%
#IMport Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Dataset Heart Disease.csv")
data.drop('Unnamed: 0', axis=1, inplace=True)
data
# Out:
#       age  sex  chest pain type  resting bps  cholesterol  \
# 0      40    1                2          140        289.0
# 1      49    0                3          160        180.0
# 2      37    1                2          130        283.0
# 3      48    0                4          138        214.0
# 4      54    1                3          150        195.0
# ...   ...  ...              ...          ...          ...
# 1043   68    0                3          120        211.0
# 1044   44    0                3          108        141.0
# 1045   52    1                1          128        255.0
# 1046   59    1                4          160        273.0
# 1047   54    1                1          120        188.0
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 1                       0            0             156                0
# ...

# %%
#Explotary data Analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1048 non-null   int64
#  1   sex                  1048 non-null   int64
#  2   chest pain type      1048 non-null   int64
#  3   resting bps          1048 non-null   int64
#  4   cholesterol          1048 non-null   float64
#  5   fasting blood sugar  1048 non-null   int64
#  6   resting ecg          1048 non-null   int64
#  7   max heart rate       1048 non-null   int64
#  8   exercise angina      1048 non-null   int64
#  9   oldpeak              1048 non-null   float64
#  10  ST slope             1048 non-null   int64
#  11  target               1048 non-null   int64
# dtypes: float64(2), int64(10)
# memory usage: 98.4 KB

# %%
data.describe().T
# Out:
#                       count        mean        std   min    25%    50%    75%  \
# age                  1048.0   53.325382   9.397822  28.0   46.0   54.0   60.0
# sex                  1048.0    0.734733   0.441686   0.0    0.0    1.0    1.0
# chest pain type      1048.0    2.817748   1.118649   1.0    2.0    3.0    4.0
# resting bps          1048.0  132.613550  17.367605  92.0  120.0  130.0  140.0
# cholesterol          1048.0  245.172710  57.101359  85.0  208.0  239.0  275.0
# fasting blood sugar  1048.0    0.162214   0.368823   0.0    0.0    0.0    0.0
# resting ecg          1048.0    0.606870   0.763313   0.0    0.0    0.0    1.0
# max heart rate       1048.0  142.918893  24.427115  69.0  125.0  144.0  162.0
# exercise angina      1048.0    0.368321   0.482579   0.0    0.0    0.0    1.0
# oldpeak              1048.0    0.942366   1.100429  -0.1    0.0    0.6    1.6
# ST slope             1048.0    1.532443   0.611023   0.0    1.0    2.0    2.0
# ...

# %%
data.isna().sum()
# Out:
# age                    0
# sex                    0
# chest pain type        0
# resting bps            0
# cholesterol            0
# fasting blood sugar    0
# resting ecg            0
# max heart rate         0
# exercise angina        0
# oldpeak                0
# ST slope               0
# target                 0
# dtype: int64

# %%
#Data Visulization

# %%
fig, ax = plt.subplots(dpi=110)
sns.set_style('darkgrid')
age=sns.histplot(data=data, x='age', kde=True, bins=20)
age.set_xlabel("Age")
age.set_title("AGE DISTRIBUTION");

# %%
fig, ax = plt.subplots(dpi=110)

chol = sns.boxplot(data=data, x='target', y='cholesterol', palette='magma')
chol.set_xlabel("Target")
chol.set_ylabel("Cholesterol");
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_17328\532174773.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   chol = sns.boxplot(data=data, x='target', y='cholesterol', palette='magma')

# %%
fig, ax = plt.subplots(figsize=(8,6), dpi=90)
sns.heatmap(data.corr(), cmap='viridis', linecolor='white', linewidths=1, annot=True, fmt='.2f', vmin=-1);

# %%
import sklearn
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import tree

# %%
X = data.drop(columns='target')
col = data.drop(columns='target')
y = data['target']

X = X.values
y = y.values

# %%
#preprocessing

# %%
scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size= 0.3)

# %%
dt=tree.DecisionTreeClassifier(max_depth=4)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
y_pred = dt.predict(X_test)

for i in range(5,25,3):
    print(f'Real value: {y_test[i]}, predicted value: {round(y_pred[i])}')
# Out:
# Real value: 0, predicted value: 0
# Real value: 0, predicted value: 0
# Real value: 0, predicted value: 0
# Real value: 0, predicted value: 0
# Real value: 0, predicted value: 0
# Real value: 1, predicted value: 1
# Real value: 1, predicted value: 1

# %%
accuracy = metrics.accuracy_score(y_pred, y_test)
print(f'accuracy of the model is: {round(accuracy,3)}')
print(f'error of the model is: {round(1-accuracy,3)}')
print(f'F1 score: {round(metrics.f1_score(y_test, y_pred, pos_label=1),3)}')
# Out:
# accuracy of the model is: 0.816
# error of the model is: 0.184
# F1 score: 0.816

# %%
plt.figure(dpi=110, figsize=(30,30))

tree.plot_tree(dt,
          feature_names= col.columns,
          impurity = False,
          node_ids = True,
          proportion = True,
          rounded = True,
          precision = 2);

# %%
fig, ax = plt.subplots(dpi=110)

imp = pd.Series(dt.feature_importances_,index = col.columns).sort_values(ascending = False).plot(kind='bar');
imp.set_ylabel("Importance")
imp.set_title('Feature Importance');
